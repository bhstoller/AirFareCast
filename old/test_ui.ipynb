# %% [markdown]
# # ✈️ Flight Price Predictor
#
# ## **🔍 User Inputs**
# - **Departure Location:** **JFK**
# - **Arrival Location:** **LAX**
# - **Is Refundable?** ✅ Yes
# - **Nonstop?** ✅ Yes
# - **Departure Date:** 🗓 **March 15, 2025**
# - **Departure Time:** 🕒 **8:00 AM**
# - **Seats Remaining:** 🎟 **3**
# - **Cabin Class:** **Economy**
#
# ---
#
# ## **🎯 Predicted Price for Your Selected Flight**
# 💰 **Estimated Fare:** **$325.50 ± $50**
# 📊 **Model Accuracy:** **84% (Based on validation data)**
#
# ### ✅ **Factors Impacting Your Price**
# - 🛫 **Cabin Class:** Economy **(+15%)**
# - ✈️ **Nonstop Flight:** Yes **(+10%)**
# - ⏳ **Departure Time:** 8 AM (Peak Time) **(+5%)**
# - 🎟 **Seats Remaining:** 3 **(+20%)**
# - 📅 **Days to Departure:** 10 Days
#
# ---
#
# ## **📉 Best Time to Book (Cheapest Days)**
# ### 📈 **Price Forecast Leading Up to Departure**
# *(Dynamic line chart displaying predicted prices for each day until departure)*
#
# | Days Before Departure | Predicted Price ($) |
# |----------------------|------------------|
# | 30                  | 280              |
# | 25                  | 260              |
# | 23 📉 **Cheapest!**  | **250**          |
# | 15                  | 275              |
# | 10                  | 325              |
# | 5                   | 360              |
# | 3 📈 **Most Expensive!** | **400** |
#
# 🛑 **Recommendation:**
# 📌 **Buy now!** Prices are expected to **increase** as departure nears.
#
# ---
#
# ## **🔬 Feature Importance (Why This Price?)**
# *(Dynamic bar chart displaying feature importance for this prediction)*
#
# 📌 **Most Important Features:**
# 1️⃣ **Cabin Class**
# 2️⃣ **Seats Remaining**
# 3️⃣ **Days to Departure**
# 4️⃣ **Nonstop Flight**
#
# ---
#
# ## **🔄 Search Again?**
# 🔎 **Modify your inputs and run a new prediction!**
